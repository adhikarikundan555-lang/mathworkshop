# %% [markdown]
# <a href="https://colab.research.google.com/github/adhikarikundan555-lang/mathworkshop/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def get_unique_elements(input_list):
    return list(set(input_list))


sample_list = [1, 2, 3, 3, 3, 3, 4, 5]
print(f"Unique List: {get_unique_elements(sample_list)}")
# Out:
# Unique List: [1, 2, 3, 4, 5]

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True
num = int(input("Enter a number: "))

if is_prime(num):
    print("Prime number")
else:
    print("Not a prime number")
# Out:
# Enter a number: 2
# Prime number
